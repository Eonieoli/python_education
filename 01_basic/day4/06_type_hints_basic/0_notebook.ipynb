# %% [markdown]
# # Day 4-6교시: 타입 힌트 (1) - 기본 타입
#
# **학습 시간**: 50분
# **학습 목표**:
#
# - 타입 힌트의 필요성과 장점 이해하기
# - 기본 타입(int, str, float, bool)에 타입 힌트 적용하기
# - 매개변수와 반환 타입에 타입 힌트 지정하는 방법 익히기
# - 타입 힌트는 강제가 아닌 "힌트"임을 이해하기
# - FastAPI/Pydantic에서 타입 힌트의 중요성 인식하기
#
# ---

# %% [markdown]
# ## 📖 타입 힌트(Type Hints)란 무엇인가?
#
# ### 타입 힌트의 탄생 배경
#
# Python은 **동적 타입 언어(Dynamically Typed Language)**입니다. 이게 무슨 뜻일까요?
#
# ```python
# # Python에서는 이런 게 가능합니다
# x = 10        # x는 정수
# x = "hello"   # 갑자기 문자열이 됨!
# x = [1, 2, 3] # 이번엔 리스트!
# ```
#
# 변수의 타입을 미리 선언할 필요가 없어서 편리하지만, **문제**도 있습니다:
#
# 1. **코드 읽기 어려움**: 함수를 봤을 때 어떤 타입의 인자를 받아야 하는지 알 수 없음
# 2. **버그 발견 늦음**: 실행하기 전까지 타입 오류를 발견하기 어려움
# 3. **IDE 도움 부족**: 자동완성이나 오류 감지가 제대로 작동하지 않음
#
# 이런 문제를 해결하기 위해 Python 3.5부터 **타입 힌트(Type Hints)**가 도입되었습니다!
#
# ### 왜 타입 힌트를 배워야 할까요?
#
# 타입 힌트는 단순한 "선택 사항"이 아니라 **현대 Python 개발의 표준**이 되었습니다. 특히:
#
# **1. FastAPI에서 필수입니다!**
#
# ```python
# # FastAPI 엔드포인트 예시
# @app.get("/users/{user_id}")
# def get_user(user_id: int) -> dict:  # 타입 힌트 필수!
#     return {"id": user_id, "name": "Alice"}
# ```
#
# FastAPI는 타입 힌트를 보고:
# - 자동으로 데이터 검증을 수행합니다
# - API 문서를 자동 생성합니다
# - 잘못된 타입이 들어오면 자동으로 에러를 반환합니다
#
# **2. Pydantic 모델의 핵심입니다!**
#
# ```python
# # Pydantic 모델 예시 (FastAPI에서 사용)
# class User(BaseModel):
#     name: str      # 타입 힌트로 필드 정의!
#     age: int
#     email: str
# ```
#
# **3. 코드 품질을 크게 향상시킵니다**
#
# - 🔍 **가독성**: 함수가 무엇을 받고 무엇을 반환하는지 한눈에 알 수 있음
# - 🛠️ **IDE 지원**: VS Code가 자동완성과 오류 감지를 훨씬 잘 해줌
# - 🐛 **버그 예방**: 실행 전에 타입 오류를 IDE에서 미리 발견 가능
# - 📚 **문서화**: 별도의 문서 없이도 코드 자체가 설명서 역할
#
# ### 타입 힌트의 특징: "힌트"일 뿐입니다
#
# 중요한 점은 타입 힌트가 **강제가 아니라는 것**입니다:
#
# ```python
# def add(a: int, b: int) -> int:
#     return a + b
#
# # 이것도 실행됩니다! (IDE가 경고는 하지만)
# result = add("Hello", "World")  # 문자열을 넣어도 실행은 됨
# ```
#
# Python 인터프리터는 타입 힌트를 **무시**합니다. 하지만:
# - IDE가 경고를 보여줌
# - FastAPI/Pydantic 같은 라이브러리가 검증에 활용
# - mypy 같은 도구로 정적 타입 체크 가능
#
# ### 실무에서의 타입 힌트
#
# 요즘 Python 프로젝트에서 타입 힌트는 **선택이 아닌 필수**가 되어가고 있습니다:
#
# - ✅ 대부분의 회사가 코딩 스타일 가이드에 타입 힌트 포함 요구
# - ✅ FastAPI, Pydantic 등 주요 라이브러리가 타입 힌트 기반
# - ✅ GitHub의 Python 오픈소스 프로젝트 대부분이 타입 힌트 사용
#
# 지금 배우는 타입 힌트는 **여러분의 미래 커리어를 위한 필수 스킬**입니다! 💪
#
# ---

# %% [markdown]
# ## 1️⃣ 기본 타입 힌트: int와 str
#
# ### 타입 힌트의 기본 문법
#
# 타입 힌트는 매개변수 뒤에 `: 타입`을 붙이고, 반환 타입은 `-> 타입`으로 표시합니다.
#
# **문법 구조:**
# ```python
# def 함수명(매개변수: 타입) -> 반환타입:
#     ...
# ```
#
# 먼저 타입 힌트가 없는 함수와 있는 함수를 비교해볼까요?

# %%
# ============================================
# 비교: 타입 힌트 없음 vs 있음
# ============================================

# 타입 힌트가 없는 함수 - 무엇을 받고 반환하는지 불명확
def add_old(a, b):
    return a + b

# 타입 힌트가 있는 함수 - 명확하고 안전!
def add(a: int, b: int) -> int:
    """두 정수를 더합니다"""
    return a + b

# 사용 예시
result = add(10, 20)
print(f"10 + 20 = {result}")  # 출력: 10 + 20 = 30

# %% [markdown]
# **실행 결과:**
# ```
# 10 + 20 = 30
# ```
#
# **차이점:**
# - `add_old`: a와 b가 무슨 타입인지, 무엇을 반환하는지 알 수 없음
# - `add`: a와 b는 int, 반환값도 int라는 것이 명확함
#
# ### 💡 IDE에서의 차이
#
# VS Code에서 `add`를 사용할 때:
# 1. 마우스를 올리면 "(a: int, b: int) -> int" 표시
# 2. 자동완성이 더 정확하게 작동
# 3. 잘못된 타입을 넣으면 빨간 밑줄로 경고
#
# ---

# %% [markdown]
# ### 문자열(str) 타입 힌트
#
# 문자열을 다루는 함수도 타입 힌트로 명확하게 만들 수 있습니다.

# %%
# 문자열 타입 힌트
def greet(name: str) -> str:
    """이름을 받아 인사말을 반환합니다"""
    return f"안녕하세요, {name}님!"

# 사용 예시
message = greet("홍길동")
print(message)  # 출력: 안녕하세요, 홍길동님!

# %% [markdown]
# **실행 결과:**
# ```
# 안녕하세요, 홍길동님!
# ```
#
# **핵심 포인트:**
# - `name: str` → name 매개변수는 문자열이어야 함
# - `-> str` → 이 함수는 문자열을 반환함
# - 다른 개발자가 이 함수를 보면 바로 이해 가능!
#
# ---

# %% [markdown]
# ## 2️⃣ float와 bool 타입 힌트
#
# ### float 타입: 소수점 계산
#
# 실수(소수점이 있는 숫자)를 다룰 때는 `float` 타입을 사용합니다.

# %%
# float 타입 (소수점 계산)
def calculate_price(price: float, tax: float = 0.1) -> float:
    """가격에 세금을 더한 최종 금액을 계산합니다"""
    return price * (1 + tax)

# 사용 예시
final_price = calculate_price(10000, 0.1)
print(f"최종 가격: {final_price}원")  # 출력: 최종 가격: 11000.0원

# %% [markdown]
# **실행 결과:**
# ```
# 최종 가격: 11000.0원
# ```
#
# **주목할 점:**
# - `tax: float = 0.1` → 기본값도 타입 힌트와 함께 사용 가능!
# - float는 소수점 계산이 필요한 금액, 비율, 측정값 등에 사용
# - 세금 계산, 할인율, 환율 등 실무에서 자주 사용
#
# ---

# %% [markdown]
# ### bool 타입: True/False 판단
#
# 참/거짓을 반환하는 함수는 `bool` 타입을 명시합니다.

# %%
# bool 타입 (True/False 반환)
def is_adult(age: int) -> bool:
    """성인 여부를 판단합니다 (만 18세 이상)"""
    return age >= 18

# 사용 예시
print(is_adult(25))  # 출력: True
print(is_adult(15))  # 출력: False

# %% [markdown]
# **실행 결과:**
# ```
# True
# False
# ```
#
# **bool 타입의 활용:**
# - 검증 함수: `is_valid()`, `has_permission()`, `can_access()`
# - 조건 판단: `is_premium_user()`, `is_expired()`, `should_notify()`
# - FastAPI에서 권한 체크, 데이터 검증 등에 필수!
#
# ### 💡 네이밍 팁
#
# bool을 반환하는 함수는 보통 `is_`, `has_`, `can_`, `should_` 등으로 시작하면 의도가 명확합니다!
#
# ---

# %% [markdown]
# ## 3️⃣ 타입 힌트는 강제가 아닙니다!
#
# ### 중요한 사실: Python은 타입 힌트를 무시합니다
#
# 타입 힌트를 처음 배우는 분들이 가장 놀라는 부분입니다. Python 인터프리터는 **타입 힌트를 체크하지 않습니다!**

# %%
# 타입 힌트가 있어도 다른 타입으로 실행 가능

# 1. 정상적인 사용
result1 = add(5, 3)  # OK - int + int
print(result1)  # 출력: 8

# 2. 타입이 다른데도 실행됨!
result2 = add("Hello", "World")  # 타입 에러지만 실행은 됨!
print(result2)  # 출력: HelloWorld

# %% [markdown]
# **실행 결과:**
# ```
# 8
# HelloWorld
# ```
#
# **어?! 문자열을 넣었는데 실행이 됐어요!**
#
# 네, 맞습니다! 이것이 **타입 힌트의 본질**입니다:
#
# - ✅ Python 인터프리터는 타입 힌트를 **무시**합니다
# - ✅ 실행 중에 타입 검사를 하지 않습니다
# - ✅ 그래서 "힌트(hint)"라고 부릅니다
#
# ### 그럼 왜 타입 힌트를 쓰나요?
#
# **타입 힌트의 진짜 목적 4가지:**
#
# **1. 코드 가독성 향상 📖**
# ```python
# # 타입 힌트 없음 - 뭘 넣어야 할지 모름
# def process_data(data, count):
#     return data * count
#
# # 타입 힌트 있음 - 명확함!
# def process_data(data: str, count: int) -> str:
#     return data * count
# ```
#
# **2. IDE의 자동완성 지원 🛠️**
# - VS Code가 어떤 메서드를 사용할 수 있는지 정확히 알려줌
# - 오타를 바로 잡아줌
# - 함수 시그니처를 보여줌
#
# **3. 버그 사전 예방 🐛**
# - IDE가 타입 오류를 **빨간 밑줄**로 경고
# - 실행하기 전에 문제를 발견 가능
# - mypy 같은 도구로 자동 체크 가능
#
# **4. FastAPI/Pydantic에서 필수! ⚡**
# ```python
# # FastAPI는 타입 힌트를 보고 자동으로:
# # - 데이터 검증
# # - 문서 생성
# # - 에러 처리
# # 를 해줍니다!
# ```
#
# ### ⚠️ 실무 조언
#
# 타입 힌트는 **강제가 아니지만, 실무에서는 거의 필수**로 여겨집니다:
#
# - 대부분의 회사 코딩 스타일에 포함
# - FastAPI 프로젝트에서는 100% 필수
# - 협업할 때 다른 개발자를 위한 배려
#
# ---

# %% [markdown]
# ## 4️⃣ 실전 예제 1: 상품 정보 처리
#
# ### 실무에서 자주 사용하는 패턴
#
# 여러 타입을 조합해서 실용적인 함수를 만들어봅시다. 쇼핑몰 상품 정보를 포맷팅하는 함수입니다.

# %%
def format_product_info(name: str, price: int, stock: int) -> str:
    """상품 정보를 보기 좋게 포맷팅합니다"""
    # f-string과 천단위 구분자(:,) 사용
    return f"상품명: {name} | 가격: {price:,}원 | 재고: {stock}개"

# 실제 사용
info = format_product_info("노트북", 1500000, 5)
print(info)  # 출력: 상품명: 노트북 | 가격: 1,500,000원 | 재고: 5개

# %% [markdown]
# **실행 결과:**
# ```
# 상품명: 노트북 | 가격: 1,500,000원 | 재고: 5개
# ```
#
# **타입 힌트의 효과:**
# - `name: str` → 상품명은 문자열
# - `price: int` → 가격은 정수 (원 단위)
# - `stock: int` → 재고는 정수 (개수)
# - `-> str` → 포맷팅된 문자열 반환
#
# **FastAPI에서 활용:**
# ```python
# # FastAPI 엔드포인트에서 이렇게 사용
# @app.get("/products/{product_id}")
# def get_product(product_id: int) -> dict:
#     name = "노트북"
#     price = 1500000
#     stock = 5
#     return {
#         "info": format_product_info(name, price, stock)
#     }
# ```
#
# ### 💡 실무 팁
#
# 타입 힌트를 보면:
# 1. 함수가 무엇을 하는지 **docstring 없이도** 대충 파악 가능
# 2. 잘못된 인자를 넣으면 IDE가 **즉시 경고**
# 3. 나중에 코드를 다시 봐도 **빠르게 이해** 가능
#
# ---

# %% [markdown]
# ## 5️⃣ 실전 예제 2: 사용자 검증
#
# ### 회원가입/로그인에 필수적인 검증 함수
#
# 실무에서 가장 많이 사용하는 패턴 중 하나가 **검증 함수**입니다. 타입 힌트와 함께 구현해봅시다.

# %%
def validate_password(password: str, min_length: int = 8) -> bool:
    """비밀번호가 최소 길이를 만족하는지 확인합니다"""
    return len(password) >= min_length

def validate_email(email: str) -> bool:
    """이메일 형식이 올바른지 간단히 확인합니다"""
    # 실무에서는 정규식을 사용하지만, 여기서는 간단히
    return "@" in email and "." in email

# 테스트
print(validate_password("abc123"))  # 출력: False (8자 미만)
print(validate_password("abc12345"))  # 출력: True (8자 이상)
print(validate_email("user@example.com"))  # 출력: True
print(validate_email("invalid-email"))  # 출력: False

# %% [markdown]
# **실행 결과:**
# ```
# False
# True
# True
# False
# ```
#
# **타입 힌트의 의미:**
#
# **validate_password:**
# - `password: str` → 비밀번호는 문자열
# - `min_length: int = 8` → 최소 길이는 정수, 기본값 8
# - `-> bool` → 검증 결과(통과/실패)를 반환
#
# **validate_email:**
# - `email: str` → 이메일은 문자열
# - `-> bool` → 유효성 검증 결과
#
# ### FastAPI에서의 활용 (미리보기)
#
# 다음 주에 배울 FastAPI에서는 이런 함수들을 이렇게 사용합니다:
#
# ```python
# from pydantic import BaseModel, validator
#
# class UserCreate(BaseModel):
#     email: str
#     password: str
#
#     @validator('password')
#     def password_must_be_valid(cls, v):
#         if not validate_password(v):
#             raise ValueError('비밀번호는 8자 이상이어야 합니다')
#         return v
#
#     @validator('email')
#     def email_must_be_valid(cls, v):
#         if not validate_email(v):
#             raise ValueError('올바른 이메일 형식이 아닙니다')
#         return v
# ```
#
# ### 💡 실무 검증 함수 패턴
#
# 실무에서 검증 함수는 보통 이런 패턴을 따릅니다:
#
# 1. **함수명이 의도를 명확히** → `validate_`, `is_valid_`, `check_`
# 2. **bool 반환** → 통과/실패를 명확하게
# 3. **타입 힌트 필수** → 무엇을 검증하는지 명확하게
# 4. **docstring 작성** → 어떤 기준으로 검증하는지 설명
#
# ### ⚠️ 주의사항
#
# 위 이메일 검증은 **매우 간단한 버전**입니다. 실무에서는:
# - 정규식(regex)을 사용한 더 정교한 검증
# - 이메일 도메인 실제 존재 여부 확인
# - 임시 이메일 차단 등
#
# 더 복잡한 검증이 필요합니다. 하지만 **기본 패턴**은 동일합니다!
#
# ---

# %% [markdown]
# ## 📌 핵심 정리
#
# 이번 시간에 배운 내용을 정리해봅시다!
#
# ### 1. 타입 힌트의 기본 개념
#
# **타입 힌트란?**
# - 함수의 매개변수와 반환값의 타입을 **명시하는 문법**
# - Python 3.5부터 도입된 **현대 Python의 표준**
# - **강제가 아닌 "힌트"** - 실행 시 체크하지 않음
#
# **문법:**
# ```python
# def 함수명(매개변수: 타입, 매개변수2: 타입 = 기본값) -> 반환타입:
#     ...
# ```
#
# ### 2. 기본 타입 4가지
#
# | 타입 | 설명 | 예시 |
# |------|------|------|
# | `int` | 정수 | `age: int = 25` |
# | `str` | 문자열 | `name: str = "Alice"` |
# | `float` | 실수 (소수점) | `price: float = 19.99` |
# | `bool` | 참/거짓 | `is_active: bool = True` |
#
# ### 3. 타입 힌트의 4가지 목적
#
# 1. **📖 가독성 향상**: 코드만 봐도 무엇을 받고 반환하는지 명확
# 2. **🛠️ IDE 지원**: 자동완성, 오류 감지, 리팩토링 도구 지원
# 3. **🐛 버그 예방**: 실행 전에 타입 오류를 IDE에서 발견
# 4. **⚡ FastAPI 필수**: 자동 검증, 문서 생성, 에러 처리
#
# ### 4. 타입 힌트 사용 예시
#
# ```python
# # 기본 타입
# def add(a: int, b: int) -> int:
#     return a + b
#
# # 기본값과 함께
# def greet(name: str, formal: bool = False) -> str:
#     return f"안녕하세요, {name}님" if formal else f"안녕, {name}"
#
# # 검증 함수
# def is_valid(value: str, min_len: int = 1) -> bool:
#     return len(value) >= min_len
# ```
#
# ---
#
# ## 🎯 다음 단계
#
# **지금 바로 실습하세요!**
#
# 1. **`2_practice.py`**: 강사와 함께 실습하며 타입 힌트 추가 연습
# 2. **`3_exercise.py`**: 스스로 계산기 함수를 만들며 타입 힌트 마스터
#
# **다음 교시 (7교시) 예고:**
# - `List[int]`, `Dict[str, str]`, `Optional[str]` 등 **고급 타입 힌트**
# - FastAPI/Pydantic에서 실제로 사용하는 복잡한 타입들
# - 이것이 진짜 실무 필수 스킬입니다! 🔥
#
# ---
#
# ## 💡 기억할 점
#
# ### ✅ 반드시 기억하세요
#
# 1. **타입 힌트는 FastAPI의 핵심입니다**
#    - FastAPI는 타입 힌트로 모든 것을 합니다
#    - 지금 배우는 것이 바로 FastAPI의 기초입니다
#
# 2. **타입 힌트는 강제가 아닙니다**
#    - 잘못된 타입을 넣어도 실행은 됩니다
#    - 하지만 IDE가 경고하고, FastAPI가 검증합니다
#
# 3. **실무에서는 거의 필수입니다**
#    - 대부분의 회사가 요구합니다
#    - 협업할 때 다른 개발자를 위한 배려입니다
#
# ### ⚠️ 흔한 실수
#
# 1. **타입 힌트를 쓰고 실제로는 다른 타입을 넣는 것**
#    ```python
#    def add(a: int, b: int) -> int:
#        return str(a + b)  # ❌ int를 반환해야 하는데 str 반환!
#    ```
#
# 2. **너무 복잡하게 만드는 것**
#    ```python
#    # ❌ 너무 복잡함
#    def process(x: Union[int, str, float, bool, None]) -> ...
#
#    # ✅ 간단하게
#    def process_int(x: int) -> int:
#        ...
#    ```
#
# 3. **docstring 대신 타입 힌트만 쓰는 것**
#    - 타입 힌트는 "무엇"을 설명하지만
#    - docstring은 "왜"와 "어떻게"를 설명합니다
#    - **둘 다 필요합니다!**
#
# ---
#
# ## 🚀 여러분은 이제...
#
# ✅ 타입 힌트가 무엇이고 왜 필요한지 이해했습니다
# ✅ 기본 타입(int, str, float, bool)을 사용할 수 있습니다
# ✅ FastAPI 학습을 위한 기초를 다졌습니다
#
# **다음 시간에는 `List`, `Dict`, `Optional` 등 실전 타입 힌트를 배웁니다!**
#
# 화이팅! 💪🔥
